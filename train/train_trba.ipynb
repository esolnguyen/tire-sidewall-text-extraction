# %%
from google.colab import drive
import shutil

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
src = '/content/drive/My Drive/tire_extraction/evaluate_det.py'
dst = '/content/evaluate_det.py'
shutil.copy(src, dst)
# Out:
# '/content/evaluate_det.py'

# %%
src = '/content/drive/My Drive/tire_extraction/checkpoints/textrec/TPS-ResNet-BiLSTM-Attn.pth'
dst = '/content/TPS-ResNet-BiLSTM-Attn.pth'
shutil.copy(src, dst)
# Out:
# '/content/TPS-ResNet-BiLSTM-Attn.pth'

# %%
# !mkdir data

# %%
src = '/content/drive/My Drive/tire_extraction/data/data.zip'
dst = '/content/data/data.zip'
shutil.copy(src, dst)
# Out:
# '/content/data/data.zip'

# %%
import zipfile
import os
zip_file_path = '/content/drive/My Drive/tire_extraction/data/data.zip'
extract_dir = '/content/data/'

if not os.path.exists(extract_dir):
    os.makedirs(extract_dir)

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

print(f"Unzipped {zip_file_path} to {extract_dir}")
# !ls {extract_dir}
# Out:
# Unzipped /content/drive/My Drive/tire_extraction/data/data.zip to /content/data/
# data.zip  tire_rec  tire_rec_prepared

# %%
# !git clone https://github.com/clovaai/deep-text-recognition-benchmark.git
# Out:
# Cloning into 'deep-text-recognition-benchmark'...
# remote: Enumerating objects: 499, done.
# remote: Counting objects: 100% (225/225), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 499 (delta 208), reused 200 (delta 200), pack-reused 274 (from 1)
# Receiving objects: 100% (499/499), 3.05 MiB | 39.10 MiB/s, done.
# Resolving deltas: 100% (308/308), done.

# %%
# !pip3 install lmdb pillow torchvision nltk natsort
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.4/299.4 kB 26.3 MB/s eta 0:00:00
# ...

# %%
src = '/content/drive/My Drive/tire_extraction/checkpoints/best_accuracy.pth'
dst = '/content/best_accuracy.pth'
shutil.copy(src, dst)
# Out:
# '/content/best_accuracy.pth'

# %%
# !python3 /content/deep-text-recognition-benchmark/train.py \
  --train_data data/tire_rec_prepared/training \
  --valid_data data/tire_rec_prepared/validation \
  --select_data tire --batch_ratio 1 \
   --character "0123456789abcdefghijklmnopqrstuvwxyz" \
  --Transformation TPS --FeatureExtraction ResNet --SequenceModeling BiLSTM --Prediction Attn \
  --batch_max_length 40 \
  --data_filtering_off \
  --batch_size 384 \
  --workers 4 \
  --adam --lr 3e-4 \
  --exp_name "../drive/My Drive/tire_extraction/text_rec"

# %%
src = '/content/drive/My Drive/tire_extraction/checkpoints/textrec/best_accuracy.pth'
dst = '/content/best_accuracy.pth'
shutil.copy(src, dst)
# Out:
# '/content/best_accuracy.pth'
